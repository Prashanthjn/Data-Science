# %%
import numpy as np 
from scipy import stats 


a=np.array([78,84,92,88,75,80,85,90,87,79,78,84,92,88,75,80,85,90,87,79])
b=np.array([82,88,75,90,78,85,88,77,92,80,82,88,75,90,78,85,88,77,92,80])

t_val,p_val=stats.ttest_ind(a,b)

alpha=0.05 
dof=len(a)+len(b)-2

crit_t = stats.t.ppf(1 - alpha/2, dof)

print("H0:there is no significant difference in results of the 2 groups")

print(f"t-value:{t_val}")
print(f"p-val:{p_val}")
print(f"critical t-value:{crit_t}")

print('T-test Result:')
if np.abs(t_val) >crit_t:
    print('Significant difference found.')
else:
    print('No significant difference.')

print('P-test Result:')
if p_val < alpha:
    print('Fail to reject H0. No strong evidence of difference.')
else:
    print('Reject H0. Significant difference found.')
# Out:
# H0:there is no significant difference in results of the 2 groups
# t-value:0.16880536363378446
# p-val:0.866845086698939
# critical t-value:2.0243941639119694
# T-test Result:
# No significant difference.
# P-test Result:
# Reject H0. Significant difference found.
