# %%
import numpy as np 
from scipy import stats

a=np.array([4, 4, 7, 16, 20, 11, 13, 9, 11, 15])
b=np.array([15, 16, 14, 14, 22, 22, 23, 18, 18, 19])

t_val,p_val=stats.ttest_rel(a,b)

alpha=0.05
dof=len(a)-1

c_t=stats.t.ppf(1-alpha/2,dof)

print(f"t-value:{t_val}")
print(f"p-value:{p_val}")
print(f"critical value:{c_t}")

print('T-test:')
if np.abs(t_val) >c_t:
    print('Significant difference found.')
else:
    print('No significant difference.')

print('P-test:')
if p_val < alpha:
    print('Reject H0')
else:
    print('Fail to reject H0')
# Out:
# t-value:-4.953488372093023
# p-value:0.0007875235561560148
# critical value:2.262157162798205
# T-test:
# Significant difference found.
# P-test:
# Reject H0
