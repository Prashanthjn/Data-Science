# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (6.8.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from plotly) (2.22.1)
# Requirement already satisfied: packaging in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from plotly) (26.2)

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (2.4.6)
# Requirement already satisfied: pandas>=0.19.2 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (3.0.3)
# Requirement already satisfied: plotly>=4.1.1 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (6.8.0)
# Requirement already satisfied: six>=1.9.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (82.0.1)
# Requirement already satisfied: ipython>=5.3.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (9.13.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: decorator>=5.1.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: pexpect>4.6 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: psutil>=7 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipython>=5.3.0->cufflinks) (5.15.0)
# Requirement already satisfied: comm>=0.1.3 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from plotly>=4.1.1->cufflinks) (2.22.1)
# Requirement already satisfied: packaging in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from plotly>=4.1.1->cufflinks) (26.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from pexpect>4.6->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: wcwidth in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.1)
# Requirement already satisfied: pure-eval in /home/prashanth-j-n/Desktop/data_science/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cls
import plotly.offline as iplot

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import plotly.express as px

fig = px.line(tips,y='total_bill')

fig.show()

# %%
fig = px.bar(tips,y='tip',x='day')
fig.show()

# %%
import numpy as np
