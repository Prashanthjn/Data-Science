# %%
from collections import UserList

class MyList(UserList):
    def pop(self,s=None):
        raise RuntimeError ("deletion not allowed")
    
Li=MyList([1,2,3])
print(Li)
Li.pop()
# Out:
# [1, 2, 3]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 9
#       5         raise RuntimeError ("deletion not allowed")
#       6
#       7 Li=MyList([1,2,3])
#       8 print(Li)
# ----> 9 Li.pop()
#
# Cell In[2], line 5, in MyList.pop(self, s)
#       4     def pop(self,s=None):
# ----> 5         raise RuntimeError ("deletion not allowed")
#
# RuntimeError: deletion not allowed
