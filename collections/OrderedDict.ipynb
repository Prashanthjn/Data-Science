# %%
from collections import OrderedDict

s=OrderedDict()
s['a']=1
s['b']=4

for key,value in s.items:
    print( key,value)

# %%
from collections import OrderedDict
t=OrderedDict()

t['a']=2
t['d']=3

for key,value in t.items:
    print(key,value)

t.pop('a')

t['a']=6

for key,value in t.items:
    print(key,value)
