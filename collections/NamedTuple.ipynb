# %%
from collections import namedtuple

book=namedtuple("book",["name","price"])

b1=book("abc",210)

print(b1.name)
print(b1[0])

# %%
from collections import namedtuple

Student=namedtuple('Student',['name','age','usn'])

s= Student('pras','20','cd032')
li=['jev','21','cd020']
di={'age':'20','name':'jack','usn':'cd021'}

print(Student._make(li))   # make is used to convert the list to named tuple

print(s._asdict())   #this returns the ordered dictionary

print("named tuple",s)
# Out:
# Student(name='jev', age='21', usn='cd020')
# {'name': 'pras', 'age': '20', 'usn': 'cd032'}
# named tuple Student(name='pras', age='20', usn='cd032')
