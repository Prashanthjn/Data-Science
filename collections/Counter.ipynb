# %%
from collections import Counter

s=['a','b','c','a','a','b','b','c']
t=Counter(s)
print(t)
# Out:
# Counter({'a': 3, 'b': 3, 'c': 2})

# %%
from collections import Counter

a='ssasasasdasdoh'
print(Counter(a))
# Out:
# Counter({'s': 6, 'a': 4, 'd': 2, 'o': 1, 'h': 1})
