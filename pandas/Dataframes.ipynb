# %% [markdown]
# # Dataframes
# * it's just the collection of multiple of series

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Dataframe from dictionary

# %%
data={
    'name':['ace','bob','carry','danny','emma'],
    'age':[20,30,20,30,20],
    'usn':['cd021','cd031','cd043','cd083','cd032']
}

# %%
df=pd.DataFrame(data)
df
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043
# 3  danny   30  cd083
# 4   emma   20  cd032

# %% [markdown]
# dataframe from list

# %%
li=[
    ['john','cd032'],
    ['jack','cd031'],
    ['jerry','cd035']
    ]
cols=['name','usn']
df1=pd.DataFrame(li)          #here the headers will be from 0 to n
print(df1)
df2=pd.DataFrame(li,columns=cols)   # setting labels
df2
# Out:
#        0      1
# 0   john  cd032
# 1   jack  cd031
# 2  jerry  cd035
#     name    usn
# 0   john  cd032
# 1   jack  cd031
# 2  jerry  cd035

# %% [markdown]
# indexing of columns

# %%
df
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043
# 3  danny   30  cd083
# 4   emma   20  cd032

# %%
df[['name','age','usn']]   
#instead of indexing we should make use of column names
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043
# 3  danny   30  cd083
# 4   emma   20  cd032

# %%
df['designation']=['doctor','engineer','doctor','engineer','driver']

# %%
df
# Out:
#     name  age    usn designation
# 0    ace   20  cd021      doctor
# 1    bob   30  cd031    engineer
# 2  carry   20  cd043      doctor
# 3  danny   30  cd083    engineer
# 4   emma   20  cd032      driver

# %%
df.drop('designation',axis=1)       
#should give the axis compulsary to delete  (0 for row 1 for col)
#here the deletion doen't remove original data from dataframe permanently
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043
# 3  danny   30  cd083
# 4   emma   20  cd032

# %%
df.drop(0,axis=0)
# Out:
#     name  age    usn designation
# 1    bob   30  cd031    engineer
# 2  carry   20  cd043      doctor
# 3  danny   30  cd083    engineer
# 4   emma   20  cd032      driver

# %%
df.drop('designation',axis=1,inplace=True)

# %%
df
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043
# 3  danny   30  cd083
# 4   emma   20  cd032

# %% [markdown]
# # selecting rows

# %%
df.loc[[0,1,2]]
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043

# %%
df.iloc[1]
# Out:
# name      bob
# age        30
# usn     cd031
# Name: 1, dtype: object

# %%
df.iloc[[2,3,4]][['name','age']]   #for selecting subsets of rows and columns
# Out:
#     name  age
# 2  carry   20
# 3  danny   30
# 4   emma   20

# %% [markdown]
# conditional selection

# %%
df
# Out:
#     name  age    usn
# 0    ace   20  cd021
# 1    bob   30  cd031
# 2  carry   20  cd043
# 3  danny   30  cd083
# 4   emma   20  cd032

# %%
df[df['age']>20]
# Out:
#     name  age    usn
# 1    bob   30  cd031
# 3  danny   30  cd083

# %%
df[([df['age']>20]) and (df['usn']=='cd031')]
# Out:
#   name  age    usn
# 1  bob   30  cd031

# %%
df [ (df['age']>20) | (df['usn'] == 'cd031')]
# Out:
#     name  age    usn
# 1    bob   30  cd031
# 3  danny   30  cd083
