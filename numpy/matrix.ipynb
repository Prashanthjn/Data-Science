# %%
import numpy as np

# %%
# matrix multiplication
a=np.array([
    [1,2],
    [3,4]
])

# %%
b=np.array([
    [5,6],
    [7,8]
])

# %%
a@b
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(a,b)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a.transpose()
# Out:
# array([[1, 3],
#        [2, 4]])
